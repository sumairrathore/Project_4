# %%
import pandas as pd

# %%
df_15 = pd.read_csv('players_15.csv')
df_15.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# ...

# %%
df_16 = pd.read_csv('players_16.csv')
df_16.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/16...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   28  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   30  1985-02-05
# 2          A. Robben                         Arjen Robben   31  1984-01-23
# 3           M. Neuer                         Manuel Neuer   29  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   28  1987-01-24
#
#    height_cm  weight_kg  nationality               club  ...   lwb   ldm  \
# ...

# %%
df_17 = pd.read_csv('players_17.csv')
df_17.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   31  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   29  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   24  1992-02-05
# 3           M. Neuer                         Manuel Neuer   30  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   29  1987-01-24
#
#    height_cm  weight_kg nationality               club  ...   lwb   ldm   cdm  \
# ...

# %%
df_18 = pd.read_csv('players_18.csv')
df_18.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   25  1992-02-05
# 3           M. Neuer                         Manuel Neuer   31  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   30  1987-01-24
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df_19 = pd.read_csv('players_19.csv')
df_19.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df_20 = pd.read_csv('players_20.csv')
df_20.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df_teams_and_leagues = pd.read_csv('teams_and_leagues.csv')
df_teams_and_leagues.head()
# Out:
#    url              league_name
# 0  241  Spain Primera Division
# 1   11  English Premier League
# 2    5  English Premier League
# 3  243  Spain Primera Division
# 4    1  English Premier League

# %%
# List all columns in df_15
columns_15 = df_15.columns.tolist()
columns_15
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club']]

# Display the player name columns
print("Player Names (FIFA 2015):")
player_names_15.head(10)
# Out:
# Player Names (FIFA 2015):
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27        169
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29        185
# 2          A. Robben                         Arjen Robben   30        180
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32        195
# 4           M. Neuer                         Manuel Neuer   28        193
# 5          L. Suárez             Luis Alberto Suárez Díaz   27        181
# 6          E. Hazard                          Eden Hazard   23        173
# 7      R. van Persie                     Robin van Persie   30        187
# 8  B. Schweinsteiger               Bastian Schweinsteiger   29        183
# 9          F. Ribéry                  Franck Bilal Ribéry   31        170
#
#    weight_kg  nationality                 club
# 0         67    Argentina         FC Barcelona
# ...

# %%
# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'sofifa_id', 'player_url', 'dob', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot']]
# Display the player name columns
print("Player Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
player_names_15.head(5)

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))

# Extract player name columns from the df_15 dataframe
player_names_15 = df_15[['short_name', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]
# Display the player name columns
print("\nPlayer Names (FIFA 2015):")
print(player_names_15.head(5))
# Out:
# Player Names (FIFA 2015):
#           short_name  sofifa_id  \
# 0           L. Messi     158023
# 1  Cristiano Ronaldo      20801
# 2          A. Robben       9014
# 3     Z. Ibrahimović      41236
# 4           M. Neuer     167495
#
#                                           player_url         dob  overall  \
# 0  https://sofifa.com/player/158023/lionel-messi/...  1987-06-24       93
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-...  1985-02-05       92
# 2  https://sofifa.com/player/9014/arjen-robben/15...  1984-01-23       90
# 3  https://sofifa.com/player/41236/zlatan-ibrahim...  1981-10-03       90
# 4  https://sofifa.com/player/167495/manuel-neuer/...  1986-03-27       90
#
#    potential  value_eur  wage_eur player_positions preferred_foot
# 0         95          0         0               CF           Left
# 1         92          0         0           LW, LM          Right
# 2         90          0         0       RM, LM, RW           Left
# ...

# %%
# Extract the desired columns from df_15
player_data_15 = df_15[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2015):")
player_data_15.head(10)
# Out:
# Player Data (FIFA 2015):
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27        169
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29        185
# 2          A. Robben                         Arjen Robben   30        180
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32        195
# 4           M. Neuer                         Manuel Neuer   28        193
# 5          L. Suárez             Luis Alberto Suárez Díaz   27        181
# 6          E. Hazard                          Eden Hazard   23        173
# 7      R. van Persie                     Robin van Persie   30        187
# 8  B. Schweinsteiger               Bastian Schweinsteiger   29        183
# 9          F. Ribéry                  Franck Bilal Ribéry   31        170
#
#    weight_kg  nationality                 club         dob player_positions  \
# ...

# %%
# Extract the desired columns from df_16
player_data_16 = df_16[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2016):")
player_data_16.head(10)
# Out:
# Player Data (FIFA 2016):
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   28        170
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   30        185
# 2          A. Robben                         Arjen Robben   31        180
# 3           M. Neuer                         Manuel Neuer   29        193
# 4          L. Suárez             Luis Alberto Suárez Díaz   28        182
# 5          E. Hazard                          Eden Hazard   24        173
# 6     Z. Ibrahimović                   Zlatan Ibrahimović   33        195
# 7             Neymar        Neymar da Silva Santos Junior   23        174
# 8       Thiago Silva             Thiago Emiliano da Silva   30        183
# 9        David Silva            David Josué Jiménez Silva   29        170
#
#    weight_kg  nationality                 club         dob player_positions  \
# ...

# %%
# Extract the desired columns from df_17
player_data_17 = df_17[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2017):")
player_data_17.head(10)
# Out:
# Player Data (FIFA 2017):
#           short_name                            long_name  age  height_cm  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   31        185
# 1           L. Messi       Lionel Andrés Messi Cuccittini   29        170
# 2             Neymar        Neymar da Silva Santos Junior   24        174
# 3           M. Neuer                         Manuel Neuer   30        193
# 4          L. Suárez             Luis Alberto Suárez Díaz   29        182
# 5             De Gea                David De Gea Quintana   25        193
# 6     Z. Ibrahimović                   Zlatan Ibrahimović   34        195
# 7            G. Bale                    Gareth Frank Bale   26        183
# 8         J. Boateng                       Jérôme Boateng   27        192
# 9     R. Lewandowski                   Robert Lewandowski   27        185
#
#    weight_kg nationality               club         dob player_positions  \
# ...

# %%
# Extract the desired columns from df_18
player_data_18 = df_18[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2018):")
player_data_18.head(10)
# Out:
# Player Data (FIFA 2018):
#           short_name                            long_name  age  height_cm  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32        185
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30        170
# 2             Neymar        Neymar da Silva Santos Junior   25        175
# 3           M. Neuer                         Manuel Neuer   31        193
# 4          L. Suárez             Luis Alberto Suárez Díaz   30        182
# 5     R. Lewandowski                   Robert Lewandowski   28        185
# 6             De Gea                David De Gea Quintana   26        193
# 7          E. Hazard                          Eden Hazard   26        173
# 8       Sergio Ramos                  Sergio Ramos García   31        183
# 9         G. Higuaín              Gonzalo Gerardo Higuaín   29        184
#
#    weight_kg nationality                 club         dob player_positions  \
# ...

# %%
# Extract the desired columns from df_19
player_data_19 = df_19[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2019):")
player_data_19.head(10)
# Out:
# Player Data (FIFA 2019):
#           short_name                            long_name  age  height_cm  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33        187
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31        170
# 2          Neymar Jr        Neymar da Silva Santos Junior   26        175
# 3             De Gea                David De Gea Quintana   27        193
# 4       K. De Bruyne                      Kevin De Bruyne   27        181
# 5       Sergio Ramos                  Sergio Ramos García   32        184
# 6          L. Suárez             Luis Alberto Suárez Díaz   31        182
# 7          L. Modrić                          Luka Modrić   32        172
# 8          E. Hazard                          Eden Hazard   27        173
# 9           J. Oblak                            Jan Oblak   25        188
#
#    weight_kg nationality                 club         dob player_positions  \
# ...

# %%
# Extract the desired columns from df_20
player_data_20 = df_20[['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'dob', 'player_positions', 'preferred_foot', 'body_type', 'player_tags', 'team_position', 'team_jersey_number', 'nation_position', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']]

# Display the extracted player data
print("Player Data (FIFA 2020):")
player_data_20.head(10)
# Out:
# Player Data (FIFA 2020):
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32        170
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34        187
# 2          Neymar Jr        Neymar da Silva Santos Junior   27        175
# 3           J. Oblak                            Jan Oblak   26        188
# 4          E. Hazard                          Eden Hazard   28        175
# 5       K. De Bruyne                      Kevin De Bruyne   28        181
# 6      M. ter Stegen                Marc-André ter Stegen   27        187
# 7        V. van Dijk                      Virgil van Dijk   27        193
# 8          L. Modrić                          Luka Modrić   33        172
# 9           M. Salah                 Mohamed  Salah Ghaly   27        175
#
#    weight_kg  nationality                 club         dob player_positions  \
# ...

# %%
# Export the extracted player data to a CSV file
player_data_15.to_csv('cleaned_data/players_cleaned_2015.csv', index=False)
player_data_16.to_csv('cleaned_data/players_cleaned_2016.csv', index=False)
player_data_17.to_csv('cleaned_data/players_cleaned_2017.csv', index=False)
player_data_18.to_csv('cleaned_data/players_cleaned_2018.csv', index=False)
player_data_19.to_csv('cleaned_data/players_cleaned_2019.csv', index=False)
player_data_20.to_csv('cleaned_data/players_cleaned_2020.csv', index=False)
