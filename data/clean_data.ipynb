# %%
import pandas as pd

# %%
df_17 = pd.read_csv('raw_data/players_17.csv')
df_17.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
df_18 = pd.read_csv('raw_data/players_18.csv')
df_18.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   30
# 1  178518   R. Nainggolan   29
# 2  203551     A. Florenzi   26
# 3  197445        D. Alaba   25
# 4  195864        P. Pogba   24
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/18_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/18_60.png     Belgium
# 2  https://cdn.sofifa.com/players/203/551/18_60.png       Italy
# 3  https://cdn.sofifa.com/players/197/445/18_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/18_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/it.png       82         83               Roma
# ...

# %%
df_19 = pd.read_csv('raw_data/players_19.csv')
df_19.head()
# Out:
#        ID           Name  Age  \
# 0  176580      L. Suárez   31
# 1  194765   A. Griezmann   27
# 2  177003      L. Modrić   32
# 3  224334       M. Acuña   26
# 4  192985   K. De Bruyne   27
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/19_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/194/765/19_60.png      France
# 2  https://cdn.sofifa.com/players/177/003/19_60.png     Croatia
# 3  https://cdn.sofifa.com/players/224/334/19_60.png   Argentina
# 4  https://cdn.sofifa.com/players/192/985/19_60.png     Belgium
#
#                                   Flag  Overall  Potential             Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       91         91     FC Barcelona
# 1  https://cdn.sofifa.com/flags/fr.png       89         89  Atlético Madrid
# 2  https://cdn.sofifa.com/flags/hr.png       91         91      Real Madrid
# 3  https://cdn.sofifa.com/flags/ar.png       81         81      Sporting CP
# ...

# %%
df_20 = pd.read_csv('raw_data/players_20.csv')
df_20.head()
# Out:
#        ID              Name  Age  \
# 0  176580         L. Suárez   32
# 1  194765      A. Griezmann   28
# 2  212198   Bruno Fernandes   24
# 3  192985      K. De Bruyne   28
# 4  224334          M. Acuña   27
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/194/765/20_60.png      France
# 2  https://cdn.sofifa.com/players/212/198/20_60.png    Portugal
# 3  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/20_60.png   Argentina
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       89         89       FC Barcelona
# 1  https://cdn.sofifa.com/flags/fr.png       89         89       FC Barcelona
# 2  https://cdn.sofifa.com/flags/pt.png       86         89  Manchester United
# ...

# %%
df_21 = pd.read_csv('raw_data/players_21.csv')
df_21.head()
# Out:
#        ID              Name  Age  \
# 0  176580         L. Suárez   33
# 1  192985      K. De Bruyne   29
# 2  212198   Bruno Fernandes   25
# 3  194765      A. Griezmann   29
# 4  224334          M. Acuña   28
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 2  https://cdn.sofifa.com/players/212/198/20_60.png    Portugal
# 3  https://cdn.sofifa.com/players/194/765/20_60.png      France
# 4  https://cdn.sofifa.com/players/224/334/20_60.png   Argentina
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       87         87    Atlético Madrid
# 1  https://cdn.sofifa.com/flags/be.png       91         91    Manchester City
# 2  https://cdn.sofifa.com/flags/pt.png       87         90  Manchester United
# ...

# %%
df_22 = pd.read_csv('raw_data/players_22.csv')
df_22.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %%
df_23 = pd.read_csv('raw_data/players_23.csv')
df_23.head()
# Out:
#        ID             Name  Age  \
# 0  209658      L. Goretzka   27
# 1  212198  Bruno Fernandes   27
# 2  224334         M. Acuña   30
# 3  192985     K. De Bruyne   31
# 4  224232       N. Barella   25
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.net/flags/de.png       87         88  FC Bayern München
# 1  https://cdn.sofifa.net/flags/pt.png       86         87  Manchester United
# 2  https://cdn.sofifa.net/flags/ar.png       85         85         Sevilla FC
# ...

# %%
# List all columns in df_17
columns_17 = df_17.columns.tolist()
columns_17
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
# ...

# %%
# Extract player name columns from the df_17 dataframe

player_names_17_1 = df_17[['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face']]

player_names_17_2 = df_17[['Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility']]

player_names_17_3 = df_17[['Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle']]

player_names_17_4 = df_17[['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

print("Player Names (FIFA 2017):")
player_names_17_1.head()
player_names_17_2.head()
player_names_17_3.head()
player_names_17_4.head()
# Out:
# Player Names (FIFA 2017):
#    GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes Best Position  \
# 0      27.0        25.0       31.0           33.0        37.0            ST
# 1      11.0        11.0       14.0            8.0        11.0           CDM
# 2       4.0         2.0        4.0            2.0         4.0           CDM
# 3       5.0         7.0       14.0           15.0         9.0            LB
# 4       5.0         6.0        2.0            4.0         3.0           CAM
#
#    Best Overall Rating
# 0                 88.0
# 1                 84.0
# 2                 85.0
# 3                 84.0
# 4                 85.0

# %%
# Extract the desired columns from df_17
player_data_17 = df_17[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2017):")
player_data_17.head()
# Out:
# Player Data (FIFA 2017):
#              Name  Age Nationality  Overall  Potential               Club  \
# 0       L. Suárez   29     Uruguay       92         92       FC Barcelona
# 1   R. Nainggolan   28     Belgium       86         86               Roma
# 2        A. Vidal   29       Chile       87         87  FC Bayern München
# 3        D. Alaba   24     Austria       86         89  FC Bayern München
# 4        P. Pogba   23      France       88         94  Manchester United
#
#     Value   Wage  Special Preferred Foot  ...  Marking  StandingTackle  \
# 0    €83M  €525K     2291          Right  ...     30.0            45.0
# 1  €37.5M  €130K     2290          Right  ...     78.0            85.0
# 2  €41.5M  €180K     2285          Right  ...     76.0            89.0
# 3  €41.5M  €140K     2279           Left  ...     81.0            83.0
# 4  €71.5M  €225K     2271          Right  ...     68.0            73.0
#
# ...

# %%
# Extract the desired columns from df_18
player_data_18 = df_18[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2018):")
player_data_18.head()
# Out:
# Player Data (FIFA 2018):
#              Name  Age Nationality  Overall  Potential               Club  \
# 0       L. Suárez   30     Uruguay       92         92       FC Barcelona
# 1   R. Nainggolan   29     Belgium       86         86               Roma
# 2     A. Florenzi   26       Italy       82         83               Roma
# 3        D. Alaba   25     Austria       85         87  FC Bayern München
# 4        P. Pogba   24      France       88         92  Manchester United
#
#     Value   Wage  Special Preferred Foot  ...  Marking  StandingTackle  \
# 0    €97M  €500K     2321          Right  ...     30.0            45.0
# 1  €42.5M  €130K     2286          Right  ...     78.0            86.0
# 2    €21M   €70K     2267          Right  ...     74.0            79.0
# 3  €38.5M  €130K     2263           Left  ...     78.0            82.0
# 4    €76M  €250K     2262          Right  ...     64.0            70.0
#
# ...

# %%
# Extract the desired columns from df_19
player_data_19 = df_19[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2019):")
player_data_19.head()
# Out:
# Player Data (FIFA 2019):
#             Name  Age Nationality  Overall  Potential             Club Value  \
# 0      L. Suárez   31     Uruguay       91         91     FC Barcelona  €80M
# 1   A. Griezmann   27      France       89         89  Atlético Madrid  €71M
# 2      L. Modrić   32     Croatia       91         91      Real Madrid  €67M
# 3       M. Acuña   26   Argentina       81         81      Sporting CP  €19M
# 4   K. De Bruyne   27     Belgium       91         91  Manchester City  €93M
#
#     Wage  Special Preferred Foot  ...  Marking  StandingTackle  SlidingTackle  \
# 0  €450K     2349          Right  ...     62.0            45.0           38.0
# 1  €140K     2293           Left  ...     59.0            54.0           48.0
# 2  €425K     2284          Right  ...     68.0            76.0           73.0
# 3   €20K     2281           Left  ...     78.0            80.0           75.0
# 4  €350K     2279          Right  ...     68.0            58.0           51.0
#
# ...

# %%
# Extract the desired columns from df_20
player_data_20 = df_20[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2020):")
player_data_20.head()
# Out:
# Player Data (FIFA 2020):
#                Name  Age Nationality  Overall  Potential               Club  \
# 0         L. Suárez   32     Uruguay       89         89       FC Barcelona
# 1      A. Griezmann   28      France       89         89       FC Barcelona
# 2   Bruno Fernandes   24    Portugal       86         89  Manchester United
# 3      K. De Bruyne   28     Belgium       91         91    Manchester City
# 4          M. Acuña   27   Argentina       82         82        Sporting CP
#
#     Value   Wage  Special Preferred Foot  ...  Marking  StandingTackle  \
# 0    €53M  €350K     2327          Right  ...      NaN            45.0
# 1    €69M  €370K     2299           Left  ...      NaN            54.0
# 2  €56.5M  €165K     2299          Right  ...      NaN            68.0
# 3    €90M  €370K     2289          Right  ...      NaN            62.0
# 4    €20M   €19K     2285           Left  ...      NaN            82.0
#
# ...

# %%
# Extract the desired columns from df_21
player_data_21 = df_21[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2021):")
player_data_21.head()
# Out:
# Player Data (FIFA 2021):
#                Name  Age Nationality  Overall  Potential               Club  \
# 0         L. Suárez   33     Uruguay       87         87    Atlético Madrid
# 1      K. De Bruyne   29     Belgium       91         91    Manchester City
# 2   Bruno Fernandes   25    Portugal       87         90  Manchester United
# 3      A. Griezmann   29      France       87         87       FC Barcelona
# 4          M. Acuña   28   Argentina       83         83         Sevilla FC
#
#     Value   Wage  Special Preferred Foot  ...  Marking  StandingTackle  \
# 0  €31.5M  €115K     2316          Right  ...      NaN            45.0
# 1    €87M  €370K     2304          Right  ...      NaN            65.0
# 2    €63M  €195K     2303          Right  ...      NaN            67.0
# 3  €50.5M  €290K     2288           Left  ...      NaN            54.0
# 4    €22M   €41K     2280           Left  ...      NaN            82.0
#
# ...

# %%
# Extract the desired columns from df_22
player_data_22 = df_22[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2022):")
player_data_22.head()
# Out:
# Player Data (FIFA 2022):
#               Name  Age Nationality  Overall  Potential                Club  \
# 0  Bruno Fernandes   26    Portugal       88         89   Manchester United
# 1      L. Goretzka   26     Germany       87         88   FC Bayern München
# 2        L. Suárez   34     Uruguay       88         88  Atlético de Madrid
# 3     K. De Bruyne   30     Belgium       91         91     Manchester City
# 4         M. Acuña   29   Argentina       84         84          Sevilla FC
#
#      Value   Wage  Special Preferred Foot  ...  Marking  StandingTackle  \
# 0  €107.5M  €250K     2341          Right  ...      NaN            73.0
# 1     €93M  €140K     2314          Right  ...      NaN            85.0
# 2   €44.5M  €135K     2307          Right  ...      NaN            45.0
# 3  €125.5M  €350K     2304          Right  ...      NaN            65.0
# 4     €37M   €45K     2292           Left  ...      NaN            84.0
#
# ...

# %%
# Extract the desired columns from df_22
player_data_23 = df_23[['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight', 'Release Clause', 'Kit Number', 'Best Overall Rating']]

# Display the extracted player data
print("Player Data (FIFA 2023):")
player_data_23.head()
# Out:
# Player Data (FIFA 2023):
#               Name  Age Nationality  Overall  Potential               Club  \
# 0      L. Goretzka   27     Germany       87         88  FC Bayern München
# 1  Bruno Fernandes   27    Portugal       86         87  Manchester United
# 2         M. Acuña   30   Argentina       85         85         Sevilla FC
# 3     K. De Bruyne   31     Belgium       91         91    Manchester City
# 4       N. Barella   25       Italy       86         89              Inter
#
#      Value   Wage  Special Preferred Foot  ...  Weak Foot  Skill Moves  \
# 0     €91M  €115K     2312          Right  ...        4.0          3.0
# 1   €78.5M  €190K     2305          Right  ...        3.0          4.0
# 2   €46.5M   €46K     2303           Left  ...        3.0          3.0
# 3  €107.5M  €350K     2303          Right  ...        5.0          4.0
# 4   €89.5M  €110K     2296          Right  ...        3.0          3.0
#
# ...

# %%
# Export the extracted player data to a CSV file
player_data_17.to_csv('cleaned_data/players_17_clean.csv', index=False)
player_data_18.to_csv('cleaned_data/players_18_clean.csv', index=False)
player_data_19.to_csv('cleaned_data/players_19_clean.csv', index=False)
player_data_20.to_csv('cleaned_data/players_20_clean.csv', index=False)
player_data_21.to_csv('cleaned_data/players_21_clean.csv', index=False)
player_data_22.to_csv('cleaned_data/players_22_clean.csv', index=False)
player_data_23.to_csv('cleaned_data/players_23_clean.csv', index=False)
